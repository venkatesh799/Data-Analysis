# %% [markdown]
# # About Index

# %%
import pandas as pd
data=pd.read_csv("http://bit.ly/drinksbycountry")
data.head()
# Out:
#        country  beer_servings  spirit_servings  wine_servings  \
# 0  Afghanistan              0                0              0
# 1      Albania             89              132             54
# 2      Algeria             25                0             14
# 3      Andorra            245              138            312
# 4       Angola            217               57             45
#
#    total_litres_of_pure_alcohol continent
# 0                           0.0      Asia
# 1                           4.9    Europe
# 2                           0.7    Africa
# 3                          12.4    Europe
# 4                           5.9    Africa

# %%
data.loc[3,'beer_servings']
# Out:
# 245

# %%
data.set_index('country',inplace=True)
data.head()
# Out:
#              beer_servings  spirit_servings  wine_servings  \
# country
# Afghanistan              0                0              0
# Albania                 89              132             54
# Algeria                 25                0             14
# Andorra                245              138            312
# Angola                 217               57             45
#
#              total_litres_of_pure_alcohol continent
# country
# Afghanistan                           0.0      Asia
# Albania                               4.9    Europe
# Algeria                               0.7    Africa
# Andorra                              12.4    Europe
# Angola                                5.9    Africa

# %% [markdown]
# # in the above we are getting 'country' in a sperate

# %%
data.index.name=None

# %% [markdown]
# # with this we can remove

# %%
data.head()
# Out:
#              beer_servings  spirit_servings  wine_servings  \
# Afghanistan              0                0              0
# Albania                 89              132             54
# Algeria                 25                0             14
# Andorra                245              138            312
# Angola                 217               57             45
#
#              total_litres_of_pure_alcohol continent
# Afghanistan                           0.0      Asia
# Albania                               4.9    Europe
# Algeria                               0.7    Africa
# Andorra                              12.4    Europe
# Angola                                5.9    Africa

# %%
data.loc['India','beer_servings']
# Out:
# 9

# %% [markdown]
# # we can get back the original index values

# %%
data.index.name='country'
data.reset_index(inplace=True)
data.head()
# Out:
#        country  beer_servings  spirit_servings  wine_servings  \
# 0  Afghanistan              0                0              0
# 1      Albania             89              132             54
# 2      Algeria             25                0             14
# 3      Andorra            245              138            312
# 4       Angola            217               57             45
#
#    total_litres_of_pure_alcohol continent
# 0                           0.0      Asia
# 1                           4.9    Europe
# 2                           0.7    Africa
# 3                          12.4    Europe
# 4                           5.9    Africa

# %% [markdown]
# # About describe method
#
# it is also a dataframe we can use loc ... methods on it

# %%
data.describe().loc['25%','beer_servings']
# Out:
# 20.0

# %% [markdown]
# # Index Part 2

# %%
data.continent.head()
# Out:
# 0      Asia
# 1    Europe
# 2    Africa
# 3    Europe
# 4    Africa
# Name: continent, dtype: object

# %%
data.set_index('country',inplace=True)
data.head()
# Out:
#              beer_servings  spirit_servings  wine_servings  \
# country
# Afghanistan              0                0              0
# Albania                 89              132             54
# Algeria                 25                0             14
# Andorra                245              138            312
# Angola                 217               57             45
#
#              total_litres_of_pure_alcohol continent
# country
# Afghanistan                           0.0      Asia
# Albania                               4.9    Europe
# Algeria                               0.7    Africa
# Andorra                              12.4    Europe
# Angola                                5.9    Africa

# %%
data.continent.head()
# Out:
# country
# Afghanistan      Asia
# Albania        Europe
# Algeria        Africa
# Andorra        Europe
# Angola         Africa
# Name: continent, dtype: object

# %%
data.continent.value_counts()
# Out:
# Africa           53
# Europe           45
# Asia             44
# North America    23
# Oceania          16
# South America    12
# Name: continent, dtype: int64

# %% [markdown]
# # sorting values

# %%
data.continent.value_counts().sort_values()
# Out:
# South America    12
# Oceania          16
# North America    23
# Asia             44
# Europe           45
# Africa           53
# Name: continent, dtype: int64

# %% [markdown]
# # sorting index

# %%
data.continent.value_counts().sort_index()
# Out:
# Africa           53
# Asia             44
# Europe           45
# North America    23
# Oceania          16
# South America    12
# Name: continent, dtype: int64

# %% [markdown]
# ## creating pandas series

# %%
people=pd.Series([1000,2000],index=['Albania','Andorra'],name='population')

# %%
people
# Out:
# Albania    1000
# Andorra    2000
# Name: population, dtype: int64

# %% [markdown]
# # cross checking with other series

# %%
data.beer_servings*people
# Out:
# Afghanistan                  NaN
# Albania                  89000.0
# Algeria                      NaN
# Andorra                 490000.0
# Angola                       NaN
# Antigua & Barbuda            NaN
# Argentina                    NaN
# Armenia                      NaN
# Australia                    NaN
# Austria                      NaN
# Azerbaijan                   NaN
# Bahamas                      NaN
# Bahrain                      NaN
# Bangladesh                   NaN
# Barbados                     NaN
# Belarus                      NaN
# Belgium                      NaN
# Belize                       NaN
# Benin                        NaN
# Bhutan                       NaN
# Bolivia                      NaN
# Bosnia-Herzegovina           NaN
# Botswana                     NaN
# Brazil                       NaN
# Brunei                       NaN
# Bulgaria                     NaN
# Burkina Faso                 NaN
# Burundi                      NaN
# ...

# %% [markdown]
# # Adding one series to another data frame

# %%
pd.concat([data,people],axis=1)
# Out:
# C:\Users\VENKATESH\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: FutureWarning: Sorting because non-concatenation axis is not aligned. A future version
# of pandas will change to not sort by default.
#
# To accept the future behavior, pass 'sort=False'.
#
# To retain the current behavior and silence the warning, pass 'sort=True'.
#
#   """Entry point for launching an IPython kernel.
#                       beer_servings  spirit_servings  wine_servings  \
# Afghanistan                       0                0              0
# Albania                          89              132             54
# Algeria                          25                0             14
# Andorra                         245              138            312
# Angola                          217               57             45
# Antigua & Barbuda               102              128             45
# Argentina                       193               25            221
# ...
