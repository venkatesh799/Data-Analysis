# %% [markdown]
# # Selecting a Column

# %%
import pandas as pd
data=pd.read_csv("Aadhar.csv")
data.head()
# Out:
#         Registrar                     Enrolment Agency          State  \
# 0  Allahabad Bank                A-Onerealtors Pvt Ltd  Uttar Pradesh
# 1  Allahabad Bank         Asha Security Guard Services  Uttar Pradesh
# 2  Allahabad Bank                    SGS INDIA PVT LTD  Uttar Pradesh
# 3  Allahabad Bank  Sri Ramraja Sarkar Lok Kalyan Trust  Uttar Pradesh
# 4  Allahabad Bank                   Transmoovers India  Uttar Pradesh
#
#     District Sub District Pin Code Gender  Age  Aadhaar generated  \
# 0  Allahabad         Meja   212303      F    7                  1
# 1  Sonbhadra  Robertsganj   231213      M    8                  1
# 2  Sultanpur    Sultanpur   227812      F   13                  1
# 3     Shamli       Shamli   247775      M    6                  1
# 4  Gorakhpur     Sahjanwa   273001      M    8                  1
#
#    Enrolment Rejected  Residents providing email  \
# 0                   0                          0
# ...

# %%
data['Registrar']
# Out:
# 0                                            Allahabad Bank
# 1                                            Allahabad Bank
# 2                                            Allahabad Bank
# 3                                            Allahabad Bank
# 4                                            Allahabad Bank
# 5                                            Allahabad Bank
# 6                                            Allahabad Bank
# 7                                            Allahabad Bank
# 8                                            Allahabad Bank
# 9                                            Allahabad Bank
# 10                                           Allahabad Bank
# 11        Atalji Janasnehi Directorate  Government of Ka...
# 12        Atalji Janasnehi Directorate  Government of Ka...
# 13        Atalji Janasnehi Directorate  Government of Ka...
# 14        Atalji Janasnehi Directorate  Government of Ka...
# 15        Atalji Janasnehi Directorate  Government of Ka...
# ...

# %%
data.Registrar
# Out:
# 0                                            Allahabad Bank
# 1                                            Allahabad Bank
# 2                                            Allahabad Bank
# 3                                            Allahabad Bank
# 4                                            Allahabad Bank
# 5                                            Allahabad Bank
# 6                                            Allahabad Bank
# 7                                            Allahabad Bank
# 8                                            Allahabad Bank
# 9                                            Allahabad Bank
# 10                                           Allahabad Bank
# 11        Atalji Janasnehi Directorate  Government of Ka...
# 12        Atalji Janasnehi Directorate  Government of Ka...
# 13        Atalji Janasnehi Directorate  Government of Ka...
# 14        Atalji Janasnehi Directorate  Government of Ka...
# 15        Atalji Janasnehi Directorate  Government of Ka...
# ...

# %%
data['Enrolment Agency']
# Out:
# 0                       A-Onerealtors Pvt Ltd
# 1                Asha Security Guard Services
# 2                           SGS INDIA PVT LTD
# 3         Sri Ramraja Sarkar Lok Kalyan Trust
# 4                          Transmoovers India
# 5                          Transmoovers India
# 6                          Transmoovers India
# 7                          Transmoovers India
# 8                          Transmoovers India
# 9                          Transmoovers India
# 10                   Vedavaag Systems Limited
# 11          Atalji Janasnehi Directorate  GOK
# 12          Atalji Janasnehi Directorate  GOK
# 13          Atalji Janasnehi Directorate  GOK
# 14          Atalji Janasnehi Directorate  GOK
# 15          Atalji Janasnehi Directorate  GOK
# 16          Atalji Janasnehi Directorate  GOK
# 17          Atalji Janasnehi Directorate  GOK
# 18          Atalji Janasnehi Directorate  GOK
# 19          Atalji Janasnehi Directorate  GOK
# ...

# %%
data.Enrolment Agency # it will not work becaues There is a Column Name
                        #in that cases we go for data['Enrolment agency']

# %% [markdown]
# # Adding new Column to the data

# %%
data['NEW']=data.State+' , '+data.District
data.head()
# Out:
#         Registrar                     Enrolment Agency          State  \
# 0  Allahabad Bank                A-Onerealtors Pvt Ltd  Uttar Pradesh
# 1  Allahabad Bank         Asha Security Guard Services  Uttar Pradesh
# 2  Allahabad Bank                    SGS INDIA PVT LTD  Uttar Pradesh
# 3  Allahabad Bank  Sri Ramraja Sarkar Lok Kalyan Trust  Uttar Pradesh
# 4  Allahabad Bank                   Transmoovers India  Uttar Pradesh
#
#     District Sub District Pin Code Gender  Age  Aadhaar generated  \
# 0  Allahabad         Meja   212303      F    7                  1
# 1  Sonbhadra  Robertsganj   231213      M    8                  1
# 2  Sultanpur    Sultanpur   227812      F   13                  1
# 3     Shamli       Shamli   247775      M    6                  1
# 4  Gorakhpur     Sahjanwa   273001      M    8                  1
#
#    Enrolment Rejected  Residents providing email  \
# 0                   0                          0
# ...
