# %%
import pandas as pd
data=pd.read_csv("http://bit.ly/imdbratings")
data.head()
# Out:
#    star_rating                     title content_rating   genre  duration  \
# 0          9.3  The Shawshank Redemption              R   Crime       142
# 1          9.2             The Godfather              R   Crime       175
# 2          9.1    The Godfather: Part II              R   Crime       200
# 3          9.0           The Dark Knight          PG-13  Action       152
# 4          8.9              Pulp Fiction              R   Crime       154
#
#                                          actors_list
# 0  [u'Tim Robbins', u'Morgan Freeman', u'Bob Gunt...
# 1    [u'Marlon Brando', u'Al Pacino', u'James Caan']
# 2  [u'Al Pacino', u'Robert De Niro', u'Robert Duv...
# 3  [u'Christian Bale', u'Heath Ledger', u'Aaron E...
# 4  [u'John Travolta', u'Uma Thurman', u'Samuel L....

# %%
data.drop(['actors_list','content_rating'],axis=1,inplace=True)

# %%
data.rename(columns={'star_rating':'Rating','title':'Title','genre':'Genere','duration':'Duration'},inplace=True)

# %%
data.head()
# Out:
#    Rating                     Title  Genere  Duration
# 0     9.3  The Shawshank Redemption   Crime       142
# 1     9.2             The Godfather   Crime       175
# 2     9.1    The Godfather: Part II   Crime       200
# 3     9.0           The Dark Knight  Action       152
# 4     8.9              Pulp Fiction   Crime       154

# %%
data[(data.Duration >= 100) & (data.Duration <= 200)]
# Out:
#      Rating                                              Title     Genere  \
# 0       9.3                           The Shawshank Redemption      Crime
# 1       9.2                                      The Godfather      Crime
# 2       9.1                             The Godfather: Part II      Crime
# 3       9.0                                    The Dark Knight     Action
# 4       8.9                                       Pulp Fiction      Crime
# 6       8.9                     The Good, the Bad and the Ugly    Western
# 8       8.9                                   Schindler's List  Biography
# 9       8.9                                         Fight Club      Drama
# 10      8.8  The Lord of the Rings: The Fellowship of the Ring  Adventure
# 11      8.8                                          Inception     Action
# 12      8.8     Star Wars: Episode V - The Empire Strikes Back     Action
# 13      8.8                                       Forrest Gump      Drama
# ...

# %%
data[(data.Genere == 'Action') | (data.Genere == 'Comedy')]
# Out:
#      Rating                                              Title  Genere  \
# 3       9.0                                    The Dark Knight  Action
# 11      8.8                                          Inception  Action
# 12      8.8     Star Wars: Episode V - The Empire Strikes Back  Action
# 19      8.7                                          Star Wars  Action
# 20      8.7                                         The Matrix  Action
# 25      8.6                                  Life Is Beautiful  Comedy
# 29      8.6                                        City Lights  Comedy
# 35      8.6                                       Modern Times  Comedy
# 36      8.6                                Saving Private Ryan  Action
# 37      8.6                            Raiders of the Lost Ark  Action
# 43      8.5                              The Dark Knight Rises  Action
# 44      8.5                                          Gladiator  Action
# ...

# %%
data[data.Genere.isin(['Crime','Action','Comedy'])] #For multiple or Conditions
# Out:
#      Rating                                              Title  Genere  \
# 0       9.3                           The Shawshank Redemption   Crime
# 1       9.2                                      The Godfather   Crime
# 2       9.1                             The Godfather: Part II   Crime
# 3       9.0                                    The Dark Knight  Action
# 4       8.9                                       Pulp Fiction   Crime
# 11      8.8                                          Inception  Action
# 12      8.8     Star Wars: Episode V - The Empire Strikes Back  Action
# 19      8.7                                          Star Wars  Action
# 20      8.7                                         The Matrix  Action
# 21      8.7                                        City of God   Crime
# 23      8.7                                 The Usual Suspects   Crime
# 25      8.6                                  Life Is Beautiful  Comedy
# ...
