# %%
import pandas as pd
data=pd.read_csv("http://bit.ly/drinksbycountry")
data.head()
# Out:
#        country  beer_servings  spirit_servings  wine_servings  \
# 0  Afghanistan              0                0              0
# 1      Albania             89              132             54
# 2      Algeria             25                0             14
# 3      Andorra            245              138            312
# 4       Angola            217               57             45
#
#    total_litres_of_pure_alcohol continent
# 0                           0.0      Asia
# 1                           4.9    Europe
# 2                           0.7    Africa
# 3                          12.4    Europe
# 4                           5.9    Africa

# %%
data.drop('beer_servings',axis=1,inplace=True)
data.head()
# Out:
#        country  spirit_servings  wine_servings  total_litres_of_pure_alcohol  \
# 0  Afghanistan                0              0                           0.0
# 1      Albania              132             54                           4.9
# 2      Algeria                0             14                           0.7
# 3      Andorra              138            312                          12.4
# 4       Angola               57             45                           5.9
#
#   continent
# 0      Asia
# 1    Europe
# 2    Africa
# 3    Europe
# 4    Africa

# %%
data.drop(['spirit_servings','wine_servings'],axis=1,inplace=True)
data.head()
# Out:
#        country  total_litres_of_pure_alcohol continent
# 0  Afghanistan                           0.0      Asia
# 1      Albania                           4.9    Europe
# 2      Algeria                           0.7    Africa
# 3      Andorra                          12.4    Europe
# 4       Angola                           5.9    Africa

# %%
data.rename(columns={"total_litres_of_pure_alcohol":"Alcohol"},inplace=True)
data.head()
# Out:
#        country  Alcohol continent
# 0  Afghanistan      0.0      Asia
# 1      Albania      4.9    Europe
# 2      Algeria      0.7    Africa
# 3      Andorra     12.4    Europe
# 4       Angola      5.9    Africa

# %%
data.drop(1,axis=0,inplace=True)
data.head()
# Out:
#              country  Alcohol      continent
# 2            Algeria      0.7         Africa
# 3            Andorra     12.4         Europe
# 4             Angola      5.9         Africa
# 5  Antigua & Barbuda      4.9  North America
# 6          Argentina      8.3  South America

# %%
data.sort_values('Alcohol')
# Out:
#                 country  Alcohol      continent
# 97                Libya      0.0         Africa
# 79                 Iran      0.0           Asia
# 90               Kuwait      0.0           Asia
# 158             Somalia      0.0         Africa
# 103            Maldives      0.0           Asia
# 106    Marshall Islands      0.0        Oceania
# 147          San Marino      0.0         Europe
# 128            Pakistan      0.0           Asia
# 46          North Korea      0.0           Asia
# 107          Mauritania      0.0         Africa
# 13           Bangladesh      0.0           Asia
# 111              Monaco      0.0         Europe
# 78            Indonesia      0.1           Asia
# 38              Comoros      0.1         Africa
# 123               Niger      0.1         Africa
# 149        Saudi Arabia      0.1           Asia
# 116             Myanmar      0.1           Asia
# 171         Timor-Leste      0.1           Asia
# 190               Yemen      0.1           Asia
# ...

# %%
import matplotlib.pyplot as plt

# %%
x=data1['country']
y=data1['Alcohol']
w=0.25
plt.bar(x,y,width=w,color='b')
plt.show()
