# %% [markdown]
# # Using String Methods in Pandas Series

# %%
import pandas as pd
data=pd.read_csv("http://bit.ly/uforeports")

# %%
data.head()
# Out:
#                    City Colors Reported Shape Reported State             Time
# 0                Ithaca             NaN       TRIANGLE    NY   6/1/1930 22:00
# 1           Willingboro             NaN          OTHER    NJ  6/30/1930 20:00
# 2               Holyoke             NaN           OVAL    CO  2/15/1931 14:00
# 3               Abilene             NaN           DISK    KS   6/1/1931 13:00
# 4  New York Worlds Fair             NaN          LIGHT    NY  4/18/1933 19:00

# %%
'hello'.upper()
# Out:
# 'HELLO'

# %% [markdown]
# # But in pandas to convert into uppercase we use 'str'

# %%
data.City.upper()  # it will not work

# %%
data.City.str.upper()
# Out:
# 0                      ITHACA
# 1                 WILLINGBORO
# 2                     HOLYOKE
# 3                     ABILENE
# 4        NEW YORK WORLDS FAIR
# 5                 VALLEY CITY
# 6                 CRATER LAKE
# 7                        ALMA
# 8                     EKLUTNA
# 9                     HUBBARD
# 10                    FONTANA
# 11                   WATERLOO
# 12                     BELTON
# 13                     KEOKUK
# 14                  LUDINGTON
# 15                FOREST HOME
# 16                LOS ANGELES
# 17                  HAPEVILLE
# 18                     ONEIDA
# 19                 BERING SEA
# 20                   NEBRASKA
# 21                        NaN
# 22                        NaN
# 23                  OWENSBORO
# 24                 WILDERNESS
# 25                  SAN DIEGO
# 26                 WILDERNESS
# 27                     CLOVIS
# 28                 LOS ALAMOS
# 29               FT. DUSCHENE
#                  ...
# ...

# %% [markdown]
# # Converting into dataframe

# %%
data[data.City.str.upper()]
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-17-7a9001b48fd4> in <module>
# ----> 1 data[data.City.str.upper()]
#
# ~\Anaconda3\lib\site-packages\pandas\core\frame.py in __getitem__(self, key)
#    2915
#    2916         # Do we have a (boolean) 1d indexer?
# -> 2917         if com.is_bool_indexer(key):
#    2918             return self._getitem_bool_array(key)
#    2919
#
# ~\Anaconda3\lib\site-packages\pandas\core\common.py in is_bool_indexer(key)
#     122             if not lib.is_bool_array(key):
#     123                 if isna(key).any():
# --> 124                     raise ValueError(na_msg)
#     125                 return False
#     126             return True
#
# ValueError: cannot index with vector containing NA / NaN values

# %% [markdown]
# # Above one not working because it contains NaN values

# %%
data3=pd.read_csv("Aadhar.csv")
data3.head()
# Out:
# C:\Users\VENKATESH\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3057: DtypeWarning: Columns (5) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
#         Registrar                     Enrolment Agency          State  \
# 0  Allahabad Bank                A-Onerealtors Pvt Ltd  Uttar Pradesh
# 1  Allahabad Bank         Asha Security Guard Services  Uttar Pradesh
# 2  Allahabad Bank                    SGS INDIA PVT LTD  Uttar Pradesh
# 3  Allahabad Bank  Sri Ramraja Sarkar Lok Kalyan Trust  Uttar Pradesh
# 4  Allahabad Bank                   Transmoovers India  Uttar Pradesh
#
#     District Sub District Pin Code Gender  Age  Aadhaar generated  \
# 0  Allahabad         Meja   212303      F    7                  1
# 1  Sonbhadra  Robertsganj   231213      M    8                  1
# 2  Sultanpur    Sultanpur   227812      F   13                  1
# ...

# %%
data3.State.str.upper()
# Out:
# 0         UTTAR PRADESH
# 1         UTTAR PRADESH
# 2         UTTAR PRADESH
# 3         UTTAR PRADESH
# 4         UTTAR PRADESH
# 5         UTTAR PRADESH
# 6         UTTAR PRADESH
# 7         UTTAR PRADESH
# 8         UTTAR PRADESH
# 9         UTTAR PRADESH
# 10        UTTAR PRADESH
# 11                ASSAM
# 12                BIHAR
# 13            KARNATAKA
# 14            KARNATAKA
# 15            KARNATAKA
# 16            KARNATAKA
# 17            KARNATAKA
# 18            KARNATAKA
# 19            KARNATAKA
# 20            KARNATAKA
# 21            KARNATAKA
# 22            KARNATAKA
# 23            KARNATAKA
# 24            KARNATAKA
# 25            KARNATAKA
# 26            KARNATAKA
# 27            KARNATAKA
# 28            KARNATAKA
# 29            KARNATAKA
#               ...
# 440788        JHARKHAND
# 440789        JHARKHAND
# 440790        JHARKHAND
# 440791        JHARKHAND
# 440792        JHARKHAND
# 440793        JHARKHAND
# 440794        JHARKHAND
# ...

# %%
data3[data3.District.str.contains('Prakasam')]
# Out:
#                                                 Registrar  \
# 1598                                        Bank Of India
# 1599                                        Bank Of India
# 39122             CSC e-Governance Services India Limited
# 39123             CSC e-Governance Services India Limited
# 39124             CSC e-Governance Services India Limited
# 39125             CSC e-Governance Services India Limited
# 39126             CSC e-Governance Services India Limited
# 39127             CSC e-Governance Services India Limited
# 39128             CSC e-Governance Services India Limited
# 39129             CSC e-Governance Services India Limited
# 39130             CSC e-Governance Services India Limited
# 63770             CSC e-Governance Services India Limited
# 63771             CSC e-Governance Services India Limited
# 63772             CSC e-Governance Services India Limited
# 63773             CSC e-Governance Services India Limited
# ...

# %% [markdown]
# ## A lot more String methods
#
# https://pandas.pydata.org/pandas-docs/stable/reference/series.html
