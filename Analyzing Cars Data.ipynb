# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np

# %%
data = pd.read_csv("CarsData.csv")

# %%
data.head()
# Out:
#     Make           Model   Type Origin DriveTrain      MSRP   Invoice  \
# 0  Acura             MDX    SUV   Asia        All  $36,945   $33,337
# 1  Acura  RSX Type S 2dr  Sedan   Asia      Front  $23,820   $21,761
# 2  Acura         TSX 4dr  Sedan   Asia      Front  $26,990   $24,647
# 3  Acura          TL 4dr  Sedan   Asia      Front  $33,195   $30,299
# 4  Acura      3.5 RL 4dr  Sedan   Asia      Front  $43,755   $39,014
#
#    EngineSize  Cylinders  Horsepower  MPG_City  MPG_Highway  Weight  \
# 0         3.5        6.0       265.0      17.0         23.0  4451.0
# 1         2.0        4.0       200.0      24.0         31.0  2778.0
# 2         2.4        4.0       200.0      22.0         29.0  3230.0
# 3         3.2        6.0       270.0      20.0         28.0  3575.0
# 4         3.5        6.0       225.0      18.0         24.0  3880.0
#
#    Wheelbase  Length
# 0      106.0   189.0
# 1      101.0   172.0
# 2      105.0   183.0
# 3      108.0   186.0
# 4      115.0   197.0

# %%
data.shape
# Out:
# (432, 15)

# %%
data.dtypes
# Out:
# Make            object
# Model           object
# Type            object
# Origin          object
# DriveTrain      object
# MSRP            object
# Invoice         object
# EngineSize     float64
# Cylinders      float64
# Horsepower     float64
# MPG_City       float64
# MPG_Highway    float64
# Weight         float64
# Wheelbase      float64
# Length         float64
# dtype: object

# %%
data.describe()
# Out:
#        EngineSize   Cylinders  Horsepower    MPG_City  MPG_Highway  \
# count  428.000000  428.000000  428.000000  428.000000   428.000000
# mean     3.196729    5.799065  215.885514   20.060748    26.843458
# std      1.108595    1.559679   71.836032    5.238218     5.741201
# min      1.300000    3.000000   73.000000   10.000000    12.000000
# 25%      2.375000    4.000000  165.000000   17.000000    24.000000
# 50%      3.000000    6.000000  210.000000   19.000000    26.000000
# 75%      3.900000    6.000000  255.000000   21.250000    29.000000
# max      8.300000   12.000000  500.000000   60.000000    66.000000
#
#             Weight   Wheelbase      Length
# count   428.000000  428.000000  428.000000
# mean   3577.953271  108.154206  186.362150
# std     758.983215    8.311813   14.357991
# min    1850.000000   89.000000  143.000000
# 25%    3104.000000  103.000000  178.000000
# 50%    3474.500000  107.000000  187.000000
# 75%    3977.750000  112.000000  194.000000
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 432 entries, 0 to 431
# Data columns (total 15 columns):
# Make           428 non-null object
# Model          428 non-null object
# Type           428 non-null object
# Origin         428 non-null object
# DriveTrain     428 non-null object
# MSRP           428 non-null object
# Invoice        428 non-null object
# EngineSize     428 non-null float64
# Cylinders      428 non-null float64
# Horsepower     428 non-null float64
# MPG_City       428 non-null float64
# MPG_Highway    428 non-null float64
# Weight         428 non-null float64
# Wheelbase      428 non-null float64
# Length         428 non-null float64
# dtypes: float64(8), object(7)
# memory usage: 50.7+ KB

# %%
data.isnull().sum()
# Out:
# Make           4
# Model          4
# Type           4
# Origin         4
# DriveTrain     4
# MSRP           4
# Invoice        4
# EngineSize     4
# Cylinders      4
# Horsepower     4
# MPG_City       4
# MPG_Highway    4
# Weight         4
# Wheelbase      4
# Length         4
# dtype: int64

# %%
data.dropna(inplace=True)

# %%
data.isnull().sum()
# Out:
# Make           0
# Model          0
# Type           0
# Origin         0
# DriveTrain     0
# MSRP           0
# Invoice        0
# EngineSize     0
# Cylinders      0
# Horsepower     0
# MPG_City       0
# MPG_Highway    0
# Weight         0
# Wheelbase      0
# Length         0
# dtype: int64

# %%
data['Make'].value_counts()
# Out:
# Toyota           28
# Chevrolet        27
# Mercedes-Benz    26
# Ford             23
# BMW              20
# Audi             19
# Nissan           17
# Honda            17
# Volkswagen       15
# Chrysler         15
# Dodge            13
# Mitsubishi       13
# Hyundai          12
# Jaguar           12
# Volvo            12
# Kia              11
# Lexus            11
# Pontiac          11
# Mazda            11
# Subaru           11
# Buick             9
# Mercury           9
# Lincoln           9
# Saturn            8
# GMC               8
# Suzuki            8
# Infiniti          8
# Cadillac          8
# Porsche           7
# Acura             7
# Saab              7
# Land Rover        3
# Jeep              3
# Oldsmobile        3
# MINI              2
# Scion             2
# Isuzu             2
# Hummer            1
# Name: Make, dtype: int64

# %%
data[data['Origin'].isin(["Asia",'Europe'])]
# Out:
#            Make                             Model    Type  Origin DriveTrain  \
# 0         Acura                               MDX     SUV    Asia        All
# 1         Acura                    RSX Type S 2dr   Sedan    Asia      Front
# 2         Acura                           TSX 4dr   Sedan    Asia      Front
# 3         Acura                            TL 4dr   Sedan    Asia      Front
# 4         Acura                        3.5 RL 4dr   Sedan    Asia      Front
# 5         Acura           3.5 RL w/Navigation 4dr   Sedan    Asia      Front
# 6         Acura            NSX coupe 2dr manual S  Sports    Asia       Rear
# 7          Audi                       A4 1.8T 4dr   Sedan  Europe      Front
# 8          Audi            A41.8T convertible 2dr   Sedan  Europe      Front
# 9          Audi                        A4 3.0 4dr   Sedan  Europe      Front
# 10         Audi         A4 3.0 Quattro 4dr manual   Sedan  Europe        All
# ...

# %%
data1=data.copy()

# %%
data.head()
# Out:
#     Make           Model   Type Origin DriveTrain      MSRP   Invoice  \
# 0  Acura             MDX    SUV   Asia        All  $36,945   $33,337
# 1  Acura  RSX Type S 2dr  Sedan   Asia      Front  $23,820   $21,761
# 2  Acura         TSX 4dr  Sedan   Asia      Front  $26,990   $24,647
# 3  Acura          TL 4dr  Sedan   Asia      Front  $33,195   $30,299
# 4  Acura      3.5 RL 4dr  Sedan   Asia      Front  $43,755   $39,014
#
#    EngineSize  Cylinders  Horsepower  MPG_City  MPG_Highway  Weight  \
# 0         3.5        6.0       265.0      17.0         23.0  4451.0
# 1         2.0        4.0       200.0      24.0         31.0  2778.0
# 2         2.4        4.0       200.0      22.0         29.0  3230.0
# 3         3.2        6.0       270.0      20.0         28.0  3575.0
# 4         3.5        6.0       225.0      18.0         24.0  3880.0
#
#    Wheelbase  Length
# 0      106.0   189.0
# 1      101.0   172.0
# 2      105.0   183.0
# 3      108.0   186.0
# 4      115.0   197.0

# %%
data1 = data1[~(data1['Weight'] > 4000)]

# %%
data1.shape
# Out:
# (325, 15)

# %%
data1["MPG_City"] = data['MPG_City']+3

# %%
data1.tail()
# Out:
#       Make                    Model   Type  Origin DriveTrain      MSRP  \
# 427  Volvo  C70 LPT convertible 2dr  Sedan  Europe      Front  $40,565
# 428  Volvo  C70 HPT convertible 2dr  Sedan  Europe      Front  $42,565
# 429  Volvo               S80 T6 4dr  Sedan  Europe      Front  $45,210
# 430  Volvo                      V40  Wagon  Europe      Front  $26,135
# 431  Volvo                     XC70  Wagon  Europe        All  $35,145
#
#       Invoice  EngineSize  Cylinders  Horsepower  MPG_City  MPG_Highway  \
# 427  $38,203          2.4        5.0       197.0      24.0         28.0
# 428  $40,083          2.3        5.0       242.0      23.0         26.0
# 429  $42,573          2.9        6.0       268.0      22.0         26.0
# 430  $24,641          1.9        4.0       170.0      25.0         29.0
# 431  $33,112          2.5        5.0       208.0      23.0         27.0
#
#      Weight  Wheelbase  Length
# 427  3450.0      105.0   186.0
# 428  3450.0      105.0   186.0
# ...

# %%
sns.relplot(x="EngineSize",y="Weight",data=data1,hue="Length")

# %%
data1.groupby('Origin')['Make'].value_counts()
# Out:
# Origin  Make
# Asia    Toyota           22
#         Honda            14
#         Nissan           13
#         Hyundai          12
#         Mazda            11
#         Mitsubishi       11
#         Subaru           11
#         Kia               8
#         Lexus             8
#         Suzuki            8
#         Acura             6
#         Infiniti          6
#         Scion             2
#         Isuzu             1
# Europe  BMW              16
#         Mercedes-Benz    16
#         Audi             14
#         Volkswagen       11
#         Volvo            11
#         Jaguar           10
#         Saab              7
#         Porsche           6
#         MINI              2
#         Land Rover        1
# USA     Chevrolet        19
#         Ford             14
#         Chrysler         12
#         Dodge            10
#         Pontiac          10
#         Saturn            8
#         Buick             7
#         Cadillac          4
# ...

# %%
def converstion(x):
    x=x.strip()
    x=x.replace('$','')
    x=x.replace(',','')
    return x

# %%
data1['Invoice'] = data1['Invoice'].apply(converstion)

# %%
data1['Invoice'] = data1['Invoice'].astype('int')

# %%
data1.head()
# Out:
#     Make                    Model   Type Origin DriveTrain      MSRP  Invoice  \
# 1  Acura           RSX Type S 2dr  Sedan   Asia      Front  $23,820     21761
# 2  Acura                  TSX 4dr  Sedan   Asia      Front  $26,990     24647
# 3  Acura                   TL 4dr  Sedan   Asia      Front  $33,195     30299
# 4  Acura               3.5 RL 4dr  Sedan   Asia      Front  $43,755     39014
# 5  Acura  3.5 RL w/Navigation 4dr  Sedan   Asia      Front  $46,100     41100
#
#    EngineSize  Cylinders  Horsepower  MPG_City  MPG_Highway  Weight  \
# 1         2.0        4.0       200.0      27.0         31.0  2778.0
# 2         2.4        4.0       200.0      25.0         29.0  3230.0
# 3         3.2        6.0       270.0      23.0         28.0  3575.0
# 4         3.5        6.0       225.0      21.0         24.0  3880.0
# 5         3.5        6.0       225.0      21.0         24.0  3893.0
#
#    Wheelbase  Length
# 1      101.0   172.0
# 2      105.0   183.0
# ...

# %%
data1.groupby('Make').Invoice.sum()
# Out:
# Make
# Acura            236799
# Audi             484044
# BMW              580800
# Buick            192252
# Cadillac         184612
# Chevrolet        399626
# Chrysler         289892
# Dodge            236721
# Ford             261864
# GMC               14877
# Honda            259632
# Hyundai          192424
# Infiniti         198163
# Isuzu             19261
# Jaguar           536456
# Jeep              67934
# Kia              102000
# Land Rover        23969
# Lexus            295491
# Lincoln          140576
# MINI              33574
# Mazda            222117
# Mercedes-Benz    622906
# Mercury           62514
# Mitsubishi       224759
# Nissan           282239
# Oldsmobile        65247
# Pontiac          215302
# Porsche          465775
# Saab             249342
# Saturn           128544
# Scion             25820
# Subaru           256273
# Suzuki           127130
# Toyota           393264
# Volkswagen       246999
# Volvo            371743
# Name: Invoice, dtype: int32

# %%
data1.DriveTrain.value_counts()
# Out:
# Front    196
# Rear      82
# All       47
# Name: DriveTrain, dtype: int64

# %%
data1.groupby('Make').DriveTrain.value_counts()
# Out:
# Make           DriveTrain
# Acura          Front          5
#                Rear           1
# Audi           All            8
#                Front          6
# BMW            Rear          13
#                All            3
# Buick          Front          7
# Cadillac       Front          2
#                Rear           2
# Chevrolet      Front         16
#                Rear           2
#                All            1
# Chrysler       Front         11
#                Rear           1
# Dodge          Front          7
#                Rear           3
# Ford           Front         10
#                Rear           3
#                All            1
# GMC            Rear           1
# Honda          Front         11
#                All            2
#                Rear           1
# Hyundai        Front         12
# Infiniti       Rear           4
#                All            1
#                Front          1
# Isuzu          Front          1
# ...

# %%
data1.head()
# Out:
#     Make                    Model   Type Origin DriveTrain      MSRP  Invoice  \
# 1  Acura           RSX Type S 2dr  Sedan   Asia      Front  $23,820     21761
# 2  Acura                  TSX 4dr  Sedan   Asia      Front  $26,990     24647
# 3  Acura                   TL 4dr  Sedan   Asia      Front  $33,195     30299
# 4  Acura               3.5 RL 4dr  Sedan   Asia      Front  $43,755     39014
# 5  Acura  3.5 RL w/Navigation 4dr  Sedan   Asia      Front  $46,100     41100
#
#    EngineSize  Cylinders  Horsepower  MPG_City  MPG_Highway  Weight  \
# 1         2.0        4.0       200.0      27.0         31.0  2778.0
# 2         2.4        4.0       200.0      25.0         29.0  3230.0
# 3         3.2        6.0       270.0      23.0         28.0  3575.0
# 4         3.5        6.0       225.0      21.0         24.0  3880.0
# 5         3.5        6.0       225.0      21.0         24.0  3893.0
#
#    Wheelbase  Length
# 1      101.0   172.0
# 2      105.0   183.0
# ...

# %%
data1[data1['Invoice'] == data1['Invoice'].max()]
# Out:
#         Make        Model    Type  Origin DriveTrain       MSRP  Invoice  \
# 338  Porsche  911 GT2 2dr  Sports  Europe       Rear  $192,465    173560
#
#      EngineSize  Cylinders  Horsepower  MPG_City  MPG_Highway  Weight  \
# 338         3.6        6.0       477.0      20.0         24.0  3131.0
#
#      Wheelbase  Length
# 338       93.0   175.0

# %%
data1.sort_values('Invoice',ascending=False)[0:5]
# Out:
#         Make                               Model    Type  Origin DriveTrain  \
# 338  Porsche                         911 GT2 2dr  Sports  Europe       Rear
# 6      Acura              NSX coupe 2dr manual S  Sports    Asia       Rear
# 203   Jaguar                       XKR coupe 2dr  Sports  Europe       Rear
# 116    Dodge        Viper SRT-10 convertible 2dr  Sports     USA       Rear
# 336  Porsche  911 Carrera 4S coupe 2dr (convert)  Sports  Europe        All
#
#           MSRP  Invoice  EngineSize  Cylinders  Horsepower  MPG_City  \
# 338  $192,465    173560         3.6        6.0       477.0      20.0
# 6     $89,765     79978         3.2        6.0       290.0      20.0
# 203   $81,995     74676         4.2        8.0       390.0      19.0
# 116   $81,795     74451         8.3       10.0       500.0      15.0
# 336   $84,165     72206         3.6        6.0       315.0      20.0
#
#      MPG_Highway  Weight  Wheelbase  Length
# 338         24.0  3131.0       93.0   175.0
# ...

# %%
sns.relplot(x='EngineSize',y="Invoice",data=data1,kind='line')

# %%
sns.relplot(x='Horsepower',y='Invoice',data=data1,kind='line')

# %%
data1.groupby('Make').Type.value_counts()
# Out:
# Make        Type
# Acura       Sedan      5
#             Sports     1
# Audi        Sedan     10
#             Sports     3
#             Wagon      1
# BMW         Sedan     11
#             Sports     4
#             Wagon      1
# Buick       Sedan      7
# Cadillac    Sedan      3
#             Sports     1
# Chevrolet   Sedan     14
#             Sports     2
#             SUV        1
#             Truck      1
#             Wagon      1
# Chrysler    Sedan     11
#             Sports     1
# Dodge       Sedan      7
#             Truck      2
#             Sports     1
# Ford        Sedan      7
#             Sports     3
#             Wagon      2
#             SUV        1
#             Truck      1
# GMC         Truck      1
# Honda       Sedan      9
#             Hybrid     2
#             SUV        2
#                       ..
# Oldsmobile  Sedan      3
# Pontiac     Sedan      7
#             SUV        1
#             Sports     1
#             Wagon      1
# ...

# %%
data1.head()
# Out:
#     Make                    Model   Type Origin DriveTrain      MSRP  Invoice  \
# 1  Acura           RSX Type S 2dr  Sedan   Asia      Front  $23,820     21761
# 2  Acura                  TSX 4dr  Sedan   Asia      Front  $26,990     24647
# 3  Acura                   TL 4dr  Sedan   Asia      Front  $33,195     30299
# 4  Acura               3.5 RL 4dr  Sedan   Asia      Front  $43,755     39014
# 5  Acura  3.5 RL w/Navigation 4dr  Sedan   Asia      Front  $46,100     41100
#
#    EngineSize  Cylinders  Horsepower  MPG_City  MPG_Highway  Weight  \
# 1         2.0        4.0       200.0      27.0         31.0  2778.0
# 2         2.4        4.0       200.0      25.0         29.0  3230.0
# 3         3.2        6.0       270.0      23.0         28.0  3575.0
# 4         3.5        6.0       225.0      21.0         24.0  3880.0
# 5         3.5        6.0       225.0      21.0         24.0  3893.0
#
#    Wheelbase  Length
# 1      101.0   172.0
# 2      105.0   183.0
# ...

# %%
sns.catplot(x="DriveTrain",y="Invoice",data=data1,kind='bar',hue="Origin",col="Type",col_wrap=2)

# %%
data.Make.nunique()
# Out:
# 38

# %%
data1.head()
# Out:
#     Make                    Model   Type Origin DriveTrain      MSRP  Invoice  \
# 1  Acura           RSX Type S 2dr  Sedan   Asia      Front  $23,820     21761
# 2  Acura                  TSX 4dr  Sedan   Asia      Front  $26,990     24647
# 3  Acura                   TL 4dr  Sedan   Asia      Front  $33,195     30299
# 4  Acura               3.5 RL 4dr  Sedan   Asia      Front  $43,755     39014
# 5  Acura  3.5 RL w/Navigation 4dr  Sedan   Asia      Front  $46,100     41100
#
#    EngineSize  Cylinders  Horsepower  MPG_City  MPG_Highway  Weight  \
# 1         2.0        4.0       200.0      27.0         31.0  2778.0
# 2         2.4        4.0       200.0      25.0         29.0  3230.0
# 3         3.2        6.0       270.0      23.0         28.0  3575.0
# 4         3.5        6.0       225.0      21.0         24.0  3880.0
# 5         3.5        6.0       225.0      21.0         24.0  3893.0
#
#    Wheelbase  Length
# 1      101.0   172.0
# 2      105.0   183.0
# ...

# %%
data1['MSRP'] = data1['MSRP'].apply(converstion)
data1.head()
# Out:
#     Make                    Model   Type Origin DriveTrain   MSRP  Invoice  \
# 1  Acura           RSX Type S 2dr  Sedan   Asia      Front  23820    21761
# 2  Acura                  TSX 4dr  Sedan   Asia      Front  26990    24647
# 3  Acura                   TL 4dr  Sedan   Asia      Front  33195    30299
# 4  Acura               3.5 RL 4dr  Sedan   Asia      Front  43755    39014
# 5  Acura  3.5 RL w/Navigation 4dr  Sedan   Asia      Front  46100    41100
#
#    EngineSize  Cylinders  Horsepower  MPG_City  MPG_Highway  Weight  \
# 1         2.0        4.0       200.0      27.0         31.0  2778.0
# 2         2.4        4.0       200.0      25.0         29.0  3230.0
# 3         3.2        6.0       270.0      23.0         28.0  3575.0
# 4         3.5        6.0       225.0      21.0         24.0  3880.0
# 5         3.5        6.0       225.0      21.0         24.0  3893.0
#
#    Wheelbase  Length
# 1      101.0   172.0
# 2      105.0   183.0
# 3      108.0   186.0
# ...

# %%
from sklearn.linear_model import LinearRegression

# %%
lm = LinearRegression()

# %%
x=data1['Horsepower']
y=data1['Invoice']

# %%
lm.fit(np.array(x).reshape(-1,1),y)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)

# %%
lm.predict([[200]])
# Out:
# array([27099.41950967])

# %%
sns.regplot(x="Horsepower",y="Invoice",data=data1)
